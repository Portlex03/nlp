# %%
import re
from concurrent.futures import ThreadPoolExecutor

import pandas as pd
import requests
from pymorphy3 import MorphAnalyzer
from razdel import tokenize
from spacy.lang.ru.stop_words import STOP_WORDS

# %%
def get_vacancy(vac_id: str) -> tuple[str, str]:
    r = requests.get(f'https://api.hh.ru/vacancies/{vac_id}', timeout=30)
    vacancy: dict = r.json()
    name = vacancy['name']
    description = vacancy['description']
    return name, description

# %%
def get_vacancies(page: int):
    params = {
        'text': 'Python OR "Программист"',
        'area': 1249, # Омск
        'page': page,
        'per_page': 100
    }
    r1 = requests.get('https://api.hh.ru/vacancies', params)
    vacansies_row: list[dict] = r1.json()['items']
    vacansies_id = [vac['id'] for vac in vacansies_row]
    with ThreadPoolExecutor() as executor:
        result = executor.map(get_vacancy, vacansies_id)
    return result

# %%
vacansies = []
vacansies.extend(get_vacancies(page=0))

# %%
vacansies.extend(get_vacancies(page=1))

# %%
len(vacansies)
# Out:
# 220

# %%
df = pd.DataFrame(columns=['profession', 'description'])
for vacancy in vacansies:
    df.loc[len(df)] = vacancy
df.head(10)
# Out:
#                                           profession  \
# 0                    UI/UX дизайнер (junior/junior+)
# 1                                    Веб-программист
# 2  Администратор сайта/Контент-менеджер цветочног...
# 3                                  Android Developer
# 4                                        Тестировщик
# 5                               Frontend-разработчик
# 6                      Программист Стажер Битрикс 24
# 7                                  Flutter Developer
# 8  Стажер/Intern Системный аналитик/System analys...
# 9                                        Тестировщик
#
#                                          description
# 0  <p><strong>Привет, мы PURRWEB =^._.^=</strong>...
# 1  <p><strong>Сверхуспешная сеть автосервисов REA...
# 2  <p>З\п по результатам собеседования</p> <p><st...
# 3  <p>Создаем собственные продукты и сотрудничаем...
# 4  <p>О компании:</p> <p>Мы — ООО &quot;Технологи...
# 5  <p>Добрый день. Мы — студия разработки сайтов ...
# 6  <p>Время прочтения вакансии: 2 минуты</p> <p>Д...
# 7  <p><strong>Если ты предпочитаешь активную разр...
# 8  <strong>Обязанности:</strong> <ul> <li> <p><st...
# 9  <p>Привет, наш потенциальный крутой тестировщи...

# %%
# df.to_csv('../../datasets/pz2-hh_parsing/hh_corpus.csv', index=False)

# %% [markdown]
# ## Предобработка

# %%
morph = MorphAnalyzer(lang='ru')

def preprocess(doc: str) -> list[str]:
    doc = doc.lower()

    doc = re.sub(r'<.*?>', '', doc)

    doc = re.sub(r'[^a-zA-Zа-яА-Я\s]', '', doc)

    doc = [word.text for word in tokenize(doc)]

    doc = [morph.normal_forms(word)[0] for word in doc]

    doc = [word for word in doc if word not in STOP_WORDS]
    return doc

# %%
df.description = df.description.apply(preprocess)
df.head(20)
# Out:
#                                            profession  \
# 0                     UI/UX дизайнер (junior/junior+)
# 1                                     Веб-программист
# 2   Администратор сайта/Контент-менеджер цветочног...
# 3                                   Android Developer
# 4                                         Тестировщик
# 5                                Frontend-разработчик
# 6                       Программист Стажер Битрикс 24
# 7                                   Flutter Developer
# 8   Стажер/Intern Системный аналитик/System analys...
# 9                                         Тестировщик
# 10              Бухгалтер по расчету заработной платы
# 11               Frontend разработчик/Web-программист
# 12                                         Стажер PHP
# 13  Ведущий инженер-электрик в электротехнический ...
# 14                             Ассистент руководителя
# 15                                 Электрогазосварщик
# 16                              Стажёр Data Scientist
# 17                               IT researcher-стажер
# 18                                  Инженер-внедрения
# 19                            Системный администратор
#
#                                           description
# 0   [привет, purrweb, команда, разрабатывать, веб,...
# 1   [сверхуспешный, сеть, автосервис, reaktor, год...
# 2   [зп, результат, собеседование, работа, офис, у...
# 3   [создавать, собственный, продукт, сотрудничать...
# 4   [компания, ооо, quot, технология, сервис, quot...
# 5   [добрый, день, студия, разработка, сайт, вебди...
# 6   [время, прочтение, вакансия, минута, дать, вак...
# 7   [предпочитать, активный, разработка, рутинный,...
# 8   [обязанность, успешно, завести, проект, стажёр...
# 9   [привет, потенциальный, крутой, тестировщикм, ...
# 10  [группа, компания, bitblaze, российский, разра...
# 11  [команда, заниматься, аутсорс, направление, ра...
# 12  [начинить, карьера, php, разработчик, ведущий,...
# 13  [производственный, объединение, вэлт, ведущий,...
# 14  [компания, magnum, real, estate, девелопер, пр...
# 15  [производственный, объединение, вэлт, разработ...
# 16  [gpn, intelligence, cup, стартовый, платформа,...
# 17  [effective, it, компания, специализироваться, ...
# 18  [цифровой, индустриальный, платформа, аккредит...
# 19  [сфера, деятельность, web, разработка, индивид...

# %%
df.description = df.description.apply(" ".join)
df.to_csv('../../datasets/pz2-hh_parsing/preprocessed_hh_corpus.csv', index=False)
